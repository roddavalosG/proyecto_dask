# %% [markdown]
# <img src='images/dask-horizontal.svg' width=400>

# %% [markdown]
# ### DASK ESCALA PYTHON
#
# * #### Dask agrega herramientas para realizar analisis de datos de forma paralelizada para mayor rendimiento y rapidez:
#
# * Para paralelizar se forma un cluster compuesto por un scheduler (el cual distribuye tareas) y un worker (el cual realiza las operaciones)
# * Tiene 2 estructuras basicas: array y dataframe los cuales funcionan con NumPy y Pandas respectivamente

# %% [markdown]
# #### Creacion de un cluster con `client`
# * n_workers = numero de nodos 'worker' que realizan operaciones en el cluster
# * threads_per_worker = numero de hilos (unidades de ejecucion) dentro de cada nodo
# * limite de memoria RAM que puede utilizar cada worker
#
# Donde los hilos comparten memoria dentro del mismo worker y cada worker es una unidad de memoria aislada

# %%
from dask.distributed import Client

# Creamos el cliente para el cluster
client = Client(n_workers = 2, threads_per_worker=1, memory_limit='1GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:37301' processes=2 threads=2, memory=1.86 GiB>

# %% [markdown]
# #### Lectura de dataframe de ejemplo beer_small.csv utilizando `dask.dataframe`
# (pegar foto de lo de dataframe)
# * blocksize se refiere al tamaño de memoria que va a ocupar cada particion del dataframe

# %%
import dask.dataframe

ddf = dask.dataframe.read_csv(
    'data/beer_small.csv', blocksize = 20e5
)
