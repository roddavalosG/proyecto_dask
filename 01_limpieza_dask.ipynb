# %% [markdown]
# # Proyecto de limpieza de datos con dask

# %%
import dask.dataframe as dd
from dask.distributed import Client
import pandas as pd

# %%
# Creamos el cliente para el cluster
client = Client(n_workers = 2, threads_per_worker=1, memory_limit='1GB')
client
# Out:
# /home/nike2004/fuentes_datos/proyecto_dask/.venv/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41861 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:44923' processes=2 threads=2, memory=1.86 GiB>

# %%
beers = dd.read_csv('data/beer_small.csv', blocksize=20e5)
beers.compute()
# Out:
#        Unnamed: 0  brewery_id                                 brewery_name  \
# 0          784200         952  Great Dane Pub & Brewing Company (Downtown)
# 1         1305265          29                               Anheuser-Busch
# 2         1526298          45                             Brooklyn Brewery
# 3          450647         590                   New Glarus Brewing Company
# 4         1223094           4                     Allagash Brewing Company
# ...           ...         ...                                          ...
# 15868     1291002        2378               Kennebec Brewing Company, Inc.
# 15869     1388483         292               Kirin Brewery Company, Limited
# 15870     1535177        1534                          Brouwerij Het Anker
# 15871     1164804       10099                         Dogfish Head Brewery
# 15872      963251         739                           Brouwerij De Ranke
#
#        review_time  review_overall  review_aroma  review_appearance  \
# 0       1136269921             4.5           4.0                4.0
# 1       1234830966             4.5           4.0                3.0
# 2       1078599557             4.5           4.0                4.0
# 3       1288790879             4.5           4.5                4.5
# 4       1295320417             4.5           4.5                4.0
# ...            ...             ...           ...                ...
# 15868   1181265447             2.5           3.0                4.0
# 15869   1202955854             4.5           3.5                3.5
# 15870   1267764634             4.5           4.0                4.0
# 15871   1322275887             4.5           4.5                4.0
# 15872   1279661178             4.0           3.5                4.0
#
#       review_profilename               beer_style  review_palate  \
# 0               dirtylou             American IPA            4.0
# 1         talkinghatrack              Light Lager            3.0
# 2            PopeJonPaul   Scotch Ale / Wee Heavy            4.0
# 3            sweemzander        American Wild Ale            4.5
# 4               Jmoore50        American Wild Ale            4.0
# ...                  ...                      ...            ...
# 15868           BuckSpin           American Stout            2.5
# 15869      saztheorybook                 Happoshu            3.0
# 15870            SShelly  Belgian Strong Pale Ale            4.5
# 15871            therica   Russian Imperial Stout            4.5
# 15872             Amalak              Belgian IPA            3.5
#
#        review_taste                       beer_name  beer_abv  beer_beerid
# 0               4.0             Texas Speedbump IPA       NaN        11846
# 1               4.0                  Bud Light Lime       4.2        41821
# 2               4.5       Brooklyn Heavy Scotch Ale       7.5        16355
# 3               4.0        R&D Bourbon Barrel Kriek       5.5        60588
# 4               4.0    Allagash Victor Francenstein       9.7        56665
# ...             ...                             ...       ...          ...
# 15868           3.0         Gurglin' Sturgeon Stout       4.0         6071
# 15869           4.0                   Sparkling Hop       5.0        40030
# 15870           4.5  Cuvée Van De Keizer Rood (Red)      10.0        42538
# 15871           4.5       Miles Davis' Bitches Brew       9.0        59151
# 15872           3.5              De Ranke XX Bitter       6.2         2656
#
# [158661 rows x 14 columns]

# %%
print(beers.dtypes)
# Out:
# Unnamed: 0                      int64
# brewery_id                      int64
# brewery_name          string[pyarrow]
# review_time                     int64
# review_overall                float64
# review_aroma                  float64
# review_appearance             float64
# review_profilename    string[pyarrow]
# beer_style            string[pyarrow]
# review_palate                 float64
# review_taste                  float64
# beer_name             string[pyarrow]
# beer_abv                      float64
# beer_beerid                     int64
# dtype: object

# %%
def check_negative(column_name):
    negatives = beers[column_name] < 0
    return negatives.sum().compute()

def check_nan(column_name):
    nan = beers[column_name].isna().sum().compute()
    return nan

for col in beers.columns:
    if check_nan(col) != 0:
        print(f"La columna: {col} tiene valores nulos")
    elif beers[col].dtype == 'int64' or beers[col].dtype == 'float64':
        if check_negative(col) != 0:
            print(f"La columna: {col} tiene valores negativos")
# Out:
# La columna: brewery_name tiene valores nulos
# La columna: review_profilename tiene valores nulos
# La columna: beer_abv tiene valores nulos

# %%
print(beers.dtypes)
# Out:
# Unnamed: 0                      int64
# brewery_id                      int64
# brewery_name          string[pyarrow]
# review_time                     int64
# review_overall                float64
# review_aroma                  float64
# review_appearance             float64
# review_profilename    string[pyarrow]
# beer_style            string[pyarrow]
# review_palate                 float64
# review_taste                  float64
# beer_name             string[pyarrow]
# beer_abv                      float64
# beer_beerid                     int64
# dtype: object

# %%
def shorten_int_float(df):
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        # Como en el analisis the arriba detectamos que no hay columnas con valores negativos entonces procedemos mas facilmente
        dtype = df[col].dtype
        if dtype == 'int64':
            max_val = df[col].max().compute()
            if max_val < 2**8:
                df[col] = df[col].astype('uint8')
            elif max_val < 2**16:
                df[col] = df[col].astype('uint16')
            elif max_val < 2**32:
                df[col] = df[col].astype('uint32')

        elif dtype == 'float64':
            max_val = df[col].max().compute()
            if max_val < 2**16:
                df[col] = df[col].astype('float16')
            elif max_val < 2**32:
                df[col] = df[col].astype('float32')

    return df

beers = shorten_int_float(beers)

# %%
def convert_review_time(ddf):

    # Se hace copia de los metadatos del ddf (esto es el esquema de las columnas)
    meta = ddf._meta.copy()

    # Cambiamos el tipo de dato en los metadatos para despues especificar en la lambda function
    meta['review_time'] = pd.to_datetime(meta['review_time'], unit='s')

    # Hacemos una lambda function sobre cada particion del ddf el cual assigna a una columna un tipo de dato diferente pero especificamos los metadatos.
    # Especificamos los metadatos para que a la hora de hacer el cambio de columna los otros tipos de datos no se cambien solos dada la inferencia de tipo de dato de dask.
    return ddf.map_partitions(lambda df: df.assign(review_time=dd.to_datetime(df['review_time'], unit='s')), meta=meta)

beers = convert_review_time(beers)

# %%
print(beers.dtypes)
# Out:
# Unnamed: 0                     uint32
# brewery_id                     uint16
# brewery_name          string[pyarrow]
# review_time            datetime64[ns]
# review_overall                float16
# review_aroma                  float16
# review_appearance             float16
# review_profilename    string[pyarrow]
# beer_style            string[pyarrow]
# review_palate                 float16
# review_taste                  float16
# beer_name             string[pyarrow]
# beer_abv                      float16
# beer_beerid                    uint32
# dtype: object

# %%
'''
en el output de arriba donde checamos las columnas obtuvimos lo siguiente:
La columna: brewery_name tiene valores nulos
La columna: review_profilename tiene valores nulos
La columna: beer_abv tiene valores nulos
'''
beers['brewery_name'] = beers['brewery_name'].fillna('N/A')
beers['review_profilename'] = beers['review_profilename'].fillna('N/A')
beers['beer_abv'] = beers['beer_abv'].fillna(-1)

beers.compute()

print(beers.isna().sum().compute())
# Out:
# Unnamed: 0            0
# brewery_id            0
# brewery_name          0
# review_time           0
# review_overall        0
# review_aroma          0
# review_appearance     0
# review_profilename    0
# beer_style            0
# review_palate         0
# review_taste          0
# beer_name             0
# beer_abv              0
# beer_beerid           0
# dtype: int64

# %%
beers.compute()
# Out:
# /home/nike2004/fuentes_datos/proyecto_dask/.venv/lib/python3.10/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#        Unnamed: 0  brewery_id                                 brewery_name  \
# 0          784200         952  Great Dane Pub & Brewing Company (Downtown)
# 1         1305265          29                               Anheuser-Busch
# 2         1526298          45                             Brooklyn Brewery
# 3          450647         590                   New Glarus Brewing Company
# 4         1223094           4                     Allagash Brewing Company
# ...           ...         ...                                          ...
# 15868     1291002        2378               Kennebec Brewing Company, Inc.
# 15869     1388483         292               Kirin Brewery Company, Limited
# 15870     1535177        1534                          Brouwerij Het Anker
# 15871     1164804       10099                         Dogfish Head Brewery
# 15872      963251         739                           Brouwerij De Ranke
#
#               review_time  review_overall  review_aroma  review_appearance  \
# 0     2006-01-03 06:32:01             4.5           4.0                4.0
# 1     2009-02-17 00:36:06             4.5           4.0                3.0
# 2     2004-03-06 18:59:17             4.5           4.0                4.0
# 3     2010-11-03 13:27:59             4.5           4.5                4.5
# 4     2011-01-18 03:13:37             4.5           4.5                4.0
# ...                   ...             ...           ...                ...
# 15868 2007-06-08 01:17:27             2.5           3.0                4.0
# 15869 2008-02-14 02:24:14             4.5           3.5                3.5
# 15870 2010-03-05 04:50:34             4.5           4.0                4.0
# 15871 2011-11-26 02:51:27             4.5           4.5                4.0
# 15872 2010-07-20 21:26:18             4.0           3.5                4.0
#
#       review_profilename               beer_style  review_palate  \
# 0               dirtylou             American IPA            4.0
# 1         talkinghatrack              Light Lager            3.0
# 2            PopeJonPaul   Scotch Ale / Wee Heavy            4.0
# 3            sweemzander        American Wild Ale            4.5
# 4               Jmoore50        American Wild Ale            4.0
# ...                  ...                      ...            ...
# 15868           BuckSpin           American Stout            2.5
# 15869      saztheorybook                 Happoshu            3.0
# 15870            SShelly  Belgian Strong Pale Ale            4.5
# 15871            therica   Russian Imperial Stout            4.5
# 15872             Amalak              Belgian IPA            3.5
#
#        review_taste                       beer_name   beer_abv  beer_beerid
# 0               4.0             Texas Speedbump IPA  -1.000000        11846
# 1               4.0                  Bud Light Lime   4.199219        41821
# 2               4.5       Brooklyn Heavy Scotch Ale   7.500000        16355
# 3               4.0        R&D Bourbon Barrel Kriek   5.500000        60588
# 4               4.0    Allagash Victor Francenstein   9.703125        56665
# ...             ...                             ...        ...          ...
# 15868           3.0         Gurglin' Sturgeon Stout   4.000000         6071
# 15869           4.0                   Sparkling Hop   5.000000        40030
# 15870           4.5  Cuvée Van De Keizer Rood (Red)  10.000000        42538
# 15871           4.5       Miles Davis' Bitches Brew   9.000000        59151
# 15872           3.5              De Ranke XX Bitter   6.199219         2656
#
# [158661 rows x 14 columns]

# %% [markdown]
# # Limpieza de datos usando unicamente pandas

# %%
beers = pd.read_csv('data/beer_small.csv')
beers
# Out:
#         Unnamed: 0  brewery_id                                 brewery_name  \
# 0           784200         952  Great Dane Pub & Brewing Company (Downtown)
# 1          1305265          29                               Anheuser-Busch
# 2          1526298          45                             Brooklyn Brewery
# 3           450647         590                   New Glarus Brewing Company
# 4          1223094           4                     Allagash Brewing Company
# ...            ...         ...                                          ...
# 158656     1291002        2378               Kennebec Brewing Company, Inc.
# 158657     1388483         292               Kirin Brewery Company, Limited
# 158658     1535177        1534                          Brouwerij Het Anker
# 158659     1164804       10099                         Dogfish Head Brewery
# 158660      963251         739                           Brouwerij De Ranke
#
#         review_time  review_overall  review_aroma  review_appearance  \
# 0        1136269921             4.5           4.0                4.0
# 1        1234830966             4.5           4.0                3.0
# 2        1078599557             4.5           4.0                4.0
# 3        1288790879             4.5           4.5                4.5
# 4        1295320417             4.5           4.5                4.0
# ...             ...             ...           ...                ...
# 158656   1181265447             2.5           3.0                4.0
# 158657   1202955854             4.5           3.5                3.5
# 158658   1267764634             4.5           4.0                4.0
# 158659   1322275887             4.5           4.5                4.0
# 158660   1279661178             4.0           3.5                4.0
#
#        review_profilename               beer_style  review_palate  \
# 0                dirtylou             American IPA            4.0
# 1          talkinghatrack              Light Lager            3.0
# 2             PopeJonPaul   Scotch Ale / Wee Heavy            4.0
# 3             sweemzander        American Wild Ale            4.5
# 4                Jmoore50        American Wild Ale            4.0
# ...                   ...                      ...            ...
# 158656           BuckSpin           American Stout            2.5
# 158657      saztheorybook                 Happoshu            3.0
# 158658            SShelly  Belgian Strong Pale Ale            4.5
# 158659            therica   Russian Imperial Stout            4.5
# 158660             Amalak              Belgian IPA            3.5
#
#         review_taste                       beer_name  beer_abv  beer_beerid
# 0                4.0             Texas Speedbump IPA       NaN        11846
# 1                4.0                  Bud Light Lime       4.2        41821
# 2                4.5       Brooklyn Heavy Scotch Ale       7.5        16355
# 3                4.0        R&D Bourbon Barrel Kriek       5.5        60588
# 4                4.0    Allagash Victor Francenstein       9.7        56665
# ...              ...                             ...       ...          ...
# 158656           3.0         Gurglin' Sturgeon Stout       4.0         6071
# 158657           4.0                   Sparkling Hop       5.0        40030
# 158658           4.5  Cuvée Van De Keizer Rood (Red)      10.0        42538
# 158659           4.5       Miles Davis' Bitches Brew       9.0        59151
# 158660           3.5              De Ranke XX Bitter       6.2         2656
#
# [158661 rows x 14 columns]

# %%
def shorten_int_float(df):
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        # Como en el analisis the arriba detectamos que no hay columnas con valores negativos entonces procedemos mas facilmente
        dtype = df[col].dtype
        if dtype == 'int64':
            max_val = df[col].max()
            if max_val < 2**8:
                df[col] = df[col].astype('uint8')
            elif max_val < 2**16:
                df[col] = df[col].astype('uint16')
            elif max_val < 2**32:
                df[col] = df[col].astype('uint32')

        elif dtype == 'float64':
            max_val = df[col].max()
            if max_val < 2**16:
                df[col] = df[col].astype('float16')
            elif max_val < 2**32:
                df[col] = df[col].astype('float32')

    return df

beers = shorten_int_float(beers)

# %%
beers['review_time'] = pd.to_datetime(beers['review_time'], unit='s')
beers['brewery_name'] = beers['brewery_name'].fillna('N/A')
beers['review_profilename'] = beers['review_profilename'].fillna('N/A')
beers['beer_abv'] = beers['beer_abv'].fillna(-1)
print(beers.isna().sum())
beers.dtypes
# Out:
# Unnamed: 0            0
# brewery_id            0
# brewery_name          0
# review_time           0
# review_overall        0
# review_aroma          0
# review_appearance     0
# review_profilename    0
# beer_style            0
# review_palate         0
# review_taste          0
# beer_name             0
# beer_abv              0
# beer_beerid           0
# dtype: int64
# Unnamed: 0                    uint32
# brewery_id                    uint16
# brewery_name                  object
# review_time           datetime64[ns]
# review_overall               float16
# review_aroma                 float16
# review_appearance            float16
# review_profilename            object
# beer_style                    object
# review_palate                float16
# review_taste                 float16
# beer_name                     object
# beer_abv                     float16
# beer_beerid                   uint32
# dtype: object
